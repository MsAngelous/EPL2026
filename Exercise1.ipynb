# %%
name = "Daniel"
birth = "1984"

# %%
def make_username(in1, in2):
    username = in1.lower().replace(" ", "") + in2
    print(username)

# %%
make_username(name, birth)
# Out:
# daniel1984

# %%
pip install variable_inspector
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
